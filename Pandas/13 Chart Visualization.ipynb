# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.close("all")

# %% [markdown]
# # Basic Plotting: `plot`

# %%
np.random.seed(123456)

# Plot a Series
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot(figsize=(9, 5))
# Out:
# <Axes: >

# %%
# Plot a DataFrame's all four columns
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
plt.figure()
df.plot(figsize=(9, 5))
# Out:
# <Axes: >

# %%
# Plot one column versus another
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
df3["A"] = pd.Series(list(range(len(df))))
df3.plot(x="A", y="B", figsize=(10, 5))

plt.show()

# %% [markdown]
# # Other Plots

# %%
# Bar plot
plt.figure()
df.iloc[350].plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ## Bar Plots

# %%
plt.figure()
df.iloc[45].plot.bar()
plt.axhline(0, color="k")

# %%
# rand : random samples from a uniform distribution over [0, 1)
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df2
# Out:
#           a         b         c         d
# 0  0.776756  0.303773  0.428600  0.070400
# 1  0.249213  0.973558  0.404596  0.777473
# 2  0.644560  0.022563  0.444410  0.804606
# 3  0.628325  0.398168  0.082784  0.099393
# 4  0.401857  0.090636  0.886385  0.424656
# 5  0.622205  0.739249  0.041461  0.933507
# 6  0.231107  0.292615  0.883645  0.695019
# 7  0.608669  0.280347  0.484302  0.625539
# 8  0.568170  0.254995  0.621211  0.385128
# 9  0.506793  0.926615  0.970202  0.308848

# %%
# Plotting the DataFrame, results in a plot of multiple bars:
df2.plot.bar()
plt.xticks(rotation=0)
plt.show()

# %%
# Produce a stacked bar plot:
df2.plot.bar(stacked=True)
plt.xticks(rotation=0)
plt.show()

# %%
# Horizontal bar plot
df2.plot.barh(stacked=True)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Histograms

# %%
df4 = pd.DataFrame(
    {
        "a": np.random.randn(1000) + 1,
        "b": np.random.randn(1000),
        "c": np.random.randn(1000) - 1,
    }
)

plt.figure()
df4.plot.hist(alpha=0.5)
plt.show()

# %%
# A stacked histogram
plt.figure()

df4.plot.hist(stacked=True, bins=20)
plt.show()

# %%
# Horizontal cumulative histogram
plt.figure()

df4["a"].plot.hist(orientation="horizontal", cumulative=True)
plt.show()

# %%
plt.figure()

df["A"].diff().hist()
# Out:
# <Axes: >

# %%
plt.figure()

df.diff().hist(color="k", alpha=0.5, bins=50)
plt.show()

# %%
# Grouped histograms
data = pd.Series(np.random.randn(1000))
data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4))
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>]],
#       dtype=object)

# %%
data = pd.DataFrame(
    {
        "a": np.random.choice(["x", "y", "z"], 1000),
        "b": np.random.choice(["e", "f", "g"], 1000),
        "c": np.random.randn(1000),
        "d": np.random.randn(1000) - 1,
    }
)

data.plot.hist(by=["a", "b"], figsize=(10, 8))
plt.show()

# %% [markdown]
# ## Boxplots

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])
df.plot.box(figsize=(9, 6))

plt.show()

# %%
# Colorized boxplot
# Use sym attribute for outliers (fliers) style
color = {
    "boxes": "DarkGreen",
    "whiskers": "DarkOrange",
    "medians": "DarkBlue",
    "caps": "Gray",
}
df.plot.box(color=color, sym="r+", figsize=(9, 6))
plt.show()

# %%
# Custom-positioned boxplot
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])
# Out:
# <Axes: >

# %%
# A stratified boxplot that uses groupings
df = pd.DataFrame(np.random.rand(10, 2), columns=["Col1", "Col2"])
df["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])
plt.figure()
bp = df.boxplot(by="X")

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=["Col1", "Col2", "Col3"])
df["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])
df["Y"] = pd.Series(["A", "B", "A", "B", "A", "B", "A", "B", "A", "B"])
df
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.727066  0.766029  0.238276  A  A
# 1  0.244290  0.150680  0.853952  A  B
# 2  0.446765  0.554378  0.291151  A  A
# 3  0.827354  0.147568  0.634590  A  B
# 4  0.621879  0.717426  0.643524  A  A
# 5  0.621587  0.932946  0.571076  B  B
# 6  0.825300  0.278493  0.878539  B  A
# 7  0.159533  0.099320  0.761676  B  B
# 8  0.192782  0.411787  0.715859  B  A
# 9  0.532257  0.884094  0.516363  B  B

# %%
plt.figure()

# Plot a subset of columns
bp = df.boxplot(column=["Col1", "Col2"], by=["X", "Y"])

# %% [markdown]
# ## Area Plot

# %%
# Area plots are stacked by default
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df.plot.area(figsize=(10, 6))
# Out:
# <Axes: >

# %%
# Produce an unstacked area plot
df.plot.area(stacked=False, figsize=(10, 6))
# Out:
# <Axes: >

# %% [markdown]
# ## Scatter Plot

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])
df["species"] = pd.Categorical(["setosa"] * 20 + ["cersicolor"] * 20 + ["virfinica"] * 10)

df.plot.scatter(x="a", y="b")
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
# Plot multiple column groups in a single axes:
ax = df.plot.scatter(x="a", y="b", color="DarkBlue", label="Group 1")
df.plot.scatter(x="c", y="b", color="Red", label="Group 2", ax=ax)
# Out:
# <Axes: xlabel='c', ylabel='b'>

# %%
# Use a column to provide colors for each point.
# Can also specify the size
df.plot.scatter(x="a", y="b", c="c", s=60)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
# Using a categorical column for colors, results in discrete colors
df.plot.scatter(x="a", y="b", c="species", cmap="viridis", s=60)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
# Bubble chart using a column as bubble size
df.plot.scatter(x="a", y="b", s=df["c"] * 200)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# ## Hexagonal Bin Plot

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])
df["b"] = df["b"] + np.arange(1000)

# A larger gridsize -> more and smaller bins
df.plot.hexbin(x="a", y="b", gridsize=20)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])
df["b"] = df["b"] + np.arange(1000)
df["z"] = np.random.uniform(0, 3, 1000)

# A larger gridsize -> more and smaller bins
df.plot.hexbin(x="a", y="b", C="z", reduce_C_function=np.max, gridsize=20)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# ## Pie Plot

# %%
series = pd.Series(3 * np.abs(np.random.randn(4)), index=["a", "b", "c", "d"], name="series")
series.plot.pie()
# Out:
# <Axes: ylabel='series'>

# %%
# A pie for each column by using "subplots=True"
df = pd.DataFrame(3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "y"])
df.plot.pie(subplots=True, figsize=(8, 4))
# Out:
# array([<Axes: ylabel='x'>, <Axes: ylabel='y'>], dtype=object)

# %%
series.plot.pie(
    labels=["AA", "BB", "CC", "DD"],
    colors=["r", "g", "b", "c"],
    autopct="%.2f",
    fontsize=20,
    figsize=(6, 6),
)
# Out:
# <Axes: ylabel='series'>

# %%
series = pd.Series([0.1] * 4, index=["a", "b", "c", "d"], name="series2")
series.plot.pie(figsize=(6, 6))
# Out:
# <Axes: ylabel='series2'>

# %% [markdown]
# # Plotting Tools
# ## Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix

df = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal="kde")

plt.show()

# %% [markdown]
# ## Density Plot

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Andrews Curves

# %%
from pandas.plotting import andrews_curves

data = pd.read_csv("data/iris.data")
plt.figure()
andrews_curves(data, "Name")
# Out:
# <Axes: >

# %% [markdown]
# ## Parallel Coordinates

# %%
from pandas.plotting import parallel_coordinates

data = pd.read_csv("data/iris.data")
plt.figure()
parallel_coordinates(data, "Name")
# Out:
# <Axes: >

# %% [markdown]
# ## Lag Plot

# %%
from pandas.plotting import lag_plot

plt.figure()
spacing = np.linspace(-99 * np.pi, 99 * np.pi, num=1000)
data = pd.Series(0.1 * np.random.randn(1000) + 0.9 * np.sin(spacing))
lag_plot(data)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# ## Autocorrelation Plot

# %%
from pandas.plotting import autocorrelation_plot

plt.figure()
spacing = np.linspace(-9 * np.pi, 9 * np.pi, num=1000)
data = pd.Series(0.4 * np.random.randn(1000) + 0.3 * np.sin(spacing))
autocorrelation_plot(data)
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# ## Bootstrap Plot

# %%
from pandas.plotting import bootstrap_plot

data = pd.Series(np.random.rand(1000))
bootstrap_plot(data, size=50, samples=500, color="grey")

# %% [markdown]
# ## RadViz

# %%
from pandas.plotting import radviz

data = pd.read_csv("data/iris.data")
plt.figure(figsize=(10, 6))
radviz(data, "Name")
# Out:
# <Axes: >

# %% [markdown]
# # Plot Formatting
# ## Setting the plot style

# %%
import matplotlib

# All the pre-built available styles
matplotlib.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ## General Plot Style Arguments

# %%
plt.figure()
ts.plot(style="k--", label="Series")
# Out:
# <Axes: >

# %% [markdown]
# ## Controlling the Legend

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()

# Hide the legend
df.plot(legend=False)
# Out:
# <Axes: >

# %% [markdown]
# ## Controlling the Labels

# %%
df.plot()
df.plot(xlabel="new x", ylabel="new y")
# Out:
# <Axes: xlabel='new x', ylabel='new y'>

# %% [markdown]
# ## Scales

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = np.exp(ts.cumsum())
ts.plot(logy=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Plotting on a Secondary y-Axis

# %%
df["A"].plot()
df["B"].plot(secondary_y=True, style="g")
# Out:
# <Axes: >

# %%
plt.figure()
ax = df.plot(secondary_y=["A", "B"])
ax.set_ylabel("CD scale")
ax.right_ax.set_ylabel("AB scale")
ax.legend(loc="lower left")
ax.right_ax.legend(loc="upper right")

# %%
plt.figure()
ax = df.plot(secondary_y=["A", "B"], mark_right=False)
# ax.legend(loc="upper left")

# %% [markdown]
# ## Suppressing Tick Resolution Adjustment

# %%
# Default behavior: notice the x-axis tick labeling behavior
plt.figure()
df["A"].plot()
# Out:
# <Axes: >

# %%
# Suppress this behavior
plt.figure()
df["A"].plot(x_compat=True)
# Out:
# <Axes: >

# %%
# Suppress default behavior when having more than one plot:
plt.figure()
with pd.plotting.plot_params.use("x_compat", True):
    df["A"].plot(c="r")
    df["B"].plot(c="g")
    df["C"].plot(c="b")

# %% [markdown]
# ## Automatic Date Tick Adjustment

# %% [markdown]
# ## Subplots

# %%
# Plot all series in a DataFrame together
df.plot()
# Out:
# <Axes: >

# %%
# Plot each series of the DataFrame on a different axis
df.plot(subplots=True, figsize=(6, 6))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# ## Using Layout and Targeting Multiple Axes

# %%
df.plot(subplots=True, layout=(2, 3), figsize=(11, 8), sharex=False)
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
# Create the Axes beforehand and pass them with ax keyword:
fig, axs = plt.subplots(4, 4, figsize=(9, 9))
plt.subplots_adjust(wspace=0.5, hspace=0.5)

target1 = [axs[0][0], axs[1][1], axs[2][2], axs[3][3]]
target2 = [axs[3][0], axs[2][1], axs[1][2], axs[0][3]]

df.plot(subplots=True, ax=target1, legend=False, sharex=False, sharey=False)
(-df).plot(subplots=True, ax=target2, legend=False, sharex=False, sharey=False)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
# To plot on a particular Axes, pass an "ax" argument to plot():
np.random.seed(123456)
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()

fig, axs = plt.subplots(nrows=2, ncols=2)
plt.subplots_adjust(wspace=0.2, hspace=0.5)

df["A"].plot(ax=axs[0, 0])
axs[0, 0].set_title("A")

df["B"].plot(ax=axs[0, 1])
axs[0, 1].set_title("B")

df["C"].plot(ax=axs[1, 0])
axs[1, 0].set_title("C")

df["D"].plot(ax=axs[1, 1])
axs[1, 1].set_title("D")
# Out:
# Text(0.5, 1.0, 'D')

# %% [markdown]
# ## Plotting with Error Bars

# %%
# Plot group means with standard deviations
#
# GENERATE THE DATA
ix3 = pd.MultiIndex.from_arrays(
    [
        ["a", "a", "a", "a", "a", "b", "b", "b", "b", "b"],
        ["foo", "foo", "foo", "bar", "bar", "foo", "foo", "bar", "bar", "bar"],
    ],
    names=["letter", "word"],
)

df3 = pd.DataFrame(
    {
        "data1": [9, 3, 2, 4, 3, 2, 4, 6, 3, 2],
        "data2": [9, 6, 5, 7, 5, 4, 5, 6, 5, 1],
    },
    index=ix3,
)

# GROUP BY INDEX LABELS AND TAKE THE MEANS AND STD FOR EACH GROUP
gp3 = df3.groupby(level=("letter", "word"))
means = gp3.mean()
errors = gp3.std()

# PLOT
fig, ax = plt.subplots()
means.plot.bar(ax=ax, yerr=errors, capsize=4, rot=0)
# Out:
# <Axes: xlabel='letter,word'>

# %%
# Asymmetrical error bars for min/max range
mins = gp3.min()
maxs = gp3.max()

# Errors should be positive, and defined in the order of lower, upper
errors = [[means[c] - mins[c], maxs[c] - means[c]] for c in df3.columns]

# Plot
fig, ax = plt.subplots()
means.plot.bar(yerr=errors, ax=ax, capsize=4, rot=0)
# Out:
# <Axes: xlabel='letter,word'>

# %% [markdown]
# ## Plotting Tables

# %%
np.random.seed(123456)
fig, ax = plt.subplots(1, 1, figsize=(13, 9))
df = pd.DataFrame(np.random.randn(5, 3), columns=["a", "b", "c"])
ax.xaxis.tick_top()  # Display x-axis ticks on top
df.plot(table=True, ax=ax)
# Out:
# <Axes: >

# %%
from pandas.plotting import table

fig, ax = plt.subplots(1, 1)
table(ax, np.round(df.describe(), 2), loc="upper right", colWidths=[0.2, 0.2, 0.2])
df.plot(ax=ax, ylim=(0, 2), legend=None)
# Out:
# <Axes: >

# %% [markdown]
# ## Colormaps

# %%
from matplotlib import cm

np.random.seed(123456)
df = pd.DataFrame(np.random.randn(1000, 10), index=ts.index)
df = df.cumsum()
plt.figure()
# df.plot(colormap="cubehelix", figsize=(10, 7)) OR...
df.plot(colormap=cm.cubehelix, figsize=(10, 7))
# Out:
# <Axes: >

# %%
dd = pd.DataFrame(np.random.randn(10, 10)).map(abs)
dd = dd.cumsum()
plt.figure()
dd.plot.bar(colormap="Greens", figsize=(10, 7))
# Out:
# <Axes: >

# %% [markdown]
# # Plotting Directly with Matplotlib

# %%
np.random.seed(123456)

price = pd.Series(
    np.random.randn(150).cumsum(),
    index=pd.date_range("2000-1-1", periods=150, freq="B"),
)

ma = price.rolling(20).mean()
mstd = price.rolling(20).std()

plt.figure(figsize=(11, 7))
plt.plot(price.index, price, "k", label="Price")

plt.plot(ma.index, ma, "b", label="Rolling Average")
plt.fill_between(mstd.index, ma - 2 * mstd, ma + 2 * mstd, color="b", alpha=0.2)

plt.legend()
plt.show()
