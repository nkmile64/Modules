# %%
import matplotlib.pyplot as plt
from matplotlib._enums import CapStyle

CapStyle.demo()
plt.show()
# Out:
# C:\Users\nkmil\AppData\Local\Temp\ipykernel_4024\3317644853.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   CapStyle.demo()
