# %%
# Controls the corners where two different line segments meet
import matplotlib.pyplot as plt
from matplotlib._enums import JoinStyle

JoinStyle.demo()
plt.show()
# Out:
# C:\Users\nkmil\AppData\Local\Temp\ipykernel_12708\2347381532.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   JoinStyle.demo()
